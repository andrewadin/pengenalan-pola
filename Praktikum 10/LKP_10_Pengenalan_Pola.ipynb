# %% [markdown]
# <a href="https://colab.research.google.com/github/andrewadin/pengenalan-pola/blob/main/Praktikum%2010/LKP_10_Pengenalan_Pola.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Kepekatan Peluang dengan Histogram

# %%
from matplotlib import pyplot
from numpy.random import normal
# generate a sample
sample = normal(size=1000)
# plot a histogram of the sample
pyplot.hist(sample, bins=10)
pyplot.show()

# %% [markdown]
# # Estimasi Kepekatan Parametrik

# %%
# contoh parametric probability density estimation
# library yang digunakan

from matplotlib import pyplot
from numpy.random import normal
from numpy import mean
from numpy import std
from scipy.stats import norm

# membangkitkan sample
sample = normal(loc=50, scale=5, size=1000)

# menghitung parameters
sample_mean = mean(sample)
sample_std = std(sample)
print('Mean=%.3f, Standard Deviation=%.3f' % (sample_mean, sample_std))

# mendefinisikan distribusi
dist = norm(sample_mean, sample_std)
values = [value for value in range(30, 70)]
probabilities = [dist.pdf(value) for value in values]

# plotting histogram and pdf
pyplot.hist(sample, bins=10, density=True)
pyplot.plot(values, probabilities)
pyplot.show()
# Out:
# Mean=49.792, Standard Deviation=4.813

# %% [markdown]
# # Estimasi Kepekatan Non-Parametrik

# %%
from matplotlib import pyplot
from numpy.random import normal
from numpy import hstack
from numpy import asarray
from numpy import exp
from sklearn.neighbors import KernelDensity

# %%
# contoh kondisi bimodal data
from matplotlib import pyplot
from numpy.random import normal
from numpy import hstack

# %%
# membangkitkan sample
sample1 = normal(loc=20, scale=5, size=300)
sample2 = normal(loc=40, scale=5, size=700)
sample = hstack((sample1, sample2))

# %%
# plot histogram
pyplot.hist(sample, bins=50)
pyplot.show()
model = KernelDensity(bandwidth=2, kernel='gaussian')
sample = sample.reshape((len(sample), 1))
model.fit(sample)
# Out:
# KernelDensity(bandwidth=2)

# %%
model = KernelDensity(bandwidth=2, kernel='gaussian')
sample = sample.reshape((len(sample), 1))
model.fit(sample)
# Out:
# KernelDensity(bandwidth=2)

# %%
# sample probabilities for a range of outcomes
values = asarray([value for value in range(1, 60)])
values = values.reshape((len(values), 1))
probabilities = model.score_samples(values)
probabilities = exp(probabilities)

# %%
# plot the histogram and pdf
pyplot.hist(sample, bins=50, density=True)
pyplot.plot(values[:], probabilities)
pyplot.show()

# %% [markdown]
# # Tugas No. 1

# %%
from matplotlib import pyplot
from numpy.random import normal

spl = [1000, 3000, 5000]
bn = [20, 40, 60]

for i in range(3):
  for j in range(3):
    # generate a sample
    sample = normal(size=spl[i])
    # plot a histogram of the sample
    pyplot.hist(sample, bins=bn[j])
    pyplot.title('Sample = ' + str(spl[i]) + ' & bin = ' + str(bn[j]))
    pyplot.show()

# %% [markdown]
# # Tugas No. 2

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import logistic

fig, ax = plt.subplots(1, 1)
mean, var, skew, kurt = logistic.stats(moments='mvsk')
x = np.linspace(logistic.ppf(0.01),logistic.ppf(0.99), 100)

ax.plot(x, logistic.pdf(x),'r-', lw=5, alpha=0.6, label='logistic pdf')

rv = logistic()

ax.plot(x, rv.pdf(x), 'k-', lw=2, label='frozen pdf')
vals = logistic.ppf([0.001, 0.5, 0.999])

np.allclose([0.001, 0.5, 0.999], logistic.cdf(vals))
r = logistic.rvs(size=1000)
ax.hist(r, density=True, bins='auto', histtype='stepfilled', alpha=0.2)
ax.set_xlim([x[0], x[-1]])
ax.legend(loc='best', frameon=False)
plt.show()

# %% [markdown]
# # Tugas No. 3

# %%
from matplotlib import pyplot
from numpy.random import normal
from numpy import hstack
from numpy import asarray
from numpy import exp
from sklearn.neighbors import KernelDensity
from matplotlib import pyplot
from numpy.random import normal
from numpy import hstack

# %%
sample1 = normal(loc=20, scale=5, size=300)
sample2 = normal(loc=40, scale=5, size=700)
sample3 = normal(loc=60, scale=5, size=900)
sample = hstack((sample1, sample2, sample3))

# %%
pyplot.hist(sample, bins=50)
pyplot.show()
model = KernelDensity(bandwidth=3, kernel='gaussian')
sample = sample.reshape((len(sample), 1))
model.fit(sample)
# Out:
# KernelDensity(bandwidth=3)

# %%
model = KernelDensity(bandwidth=3, kernel='gaussian')
sample = sample.reshape((len(sample), 1))
model.fit(sample)
# Out:
# KernelDensity(bandwidth=3)

# %%
values = asarray([value for value in range(1, 80)])
values = values.reshape((len(values), 1))
probabilities = model.score_samples(values)
probabilities = exp(probabilities)

# %%
pyplot.hist(sample, bins=50, density=True)
pyplot.plot(values[:], probabilities)
pyplot.show()
